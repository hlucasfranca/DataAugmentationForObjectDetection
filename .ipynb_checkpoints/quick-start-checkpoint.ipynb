# %% [markdown]
# # Data Augmentation For Object Detection
#
# This notebook serves as general manual to using this codebase. We cover all the major augmentations, as well as ways to combine them.

# %%
import xml.etree.ElementTree as ET
from data_aug.data_aug import *
from data_aug.bbox_util import *
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
import pickle as pkl
import glob
# %matplotlib inline

# %% [markdown]
# ## Storage Format
#
# First things first, we define how the storage formats required for images to work.
# 1. **The Image**: A OpenCV numpy array, of shape *(H x W x C)*.
# 2. **Annotations**: A numpy array of shape *N x 5* where *N* is the number of objects, one represented by each row. 5 columns represent the top-left x-coordinate, top-left y-coordinate, bottom-right x-coordinate, bottom-right y-coordinate, and the class of the object.
#
# Here is an image to aid your imagination.
#
# ![Annotation Format](ann_form.jpg)
#
# Whatever format your annotations are present in make sure, you convert them to this format.
#
# For demonstration purposes, we will be using the image above to show the transformations. The image as well as it's annotation has been provided. The annotation is a numpy array in a pickled format.

# %%
def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
        value = (root.find('filename').text,
                 int(root.find('size')[0].text),
                 int(root.find('size')[1].text),
                 member[0].text,
                 int(member[4][0].text),
                 int(member[4][1].text),
                 int(member[4][2].text),
                 int(member[4][3].text)
                 )
        arr = [float(member[4][0].text), float(member[4][1].text), float(member[4][2].text), float(member[4][3].text)]
        
    return np.array([arr])

# %%
def create_new_xml(xml_file, arr, new_xml, novo_nome):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
        value = (root.find('filename').text,
                 int(root.find('size')[0].text),
                 int(root.find('size')[1].text),
                 member[0].text,
                 int(member[4][0].text),
                 int(member[4][1].text),
                 int(member[4][2].text),
                 int(member[4][3].text)
                 )
        root.find('filename').text = novo_nome
        root.find('path').text = novo_nome
        member[4][0].text = str(int(arr[0]))
        member[4][1].text = str(int(arr[1]))
        member[4][2].text = str(int(arr[2]))
        member[4][3].text = str(int(arr[3]) )     
        
    tree.write(new_xml)

# %%
img = cv2.imread("person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
bboxes = parse_xml('person_1-0763.xml')

#inspect the bounding boxes
print(bboxes)
# Out:
# [[334. 302. 603. 512.]]

# %%
bboxes
# Out:
# array([[334., 302., 603., 512.]])

# %% [markdown]
# You can use the function `draw_rect` to plot the bounding boxes on an image.

# %%
plotted_img = draw_rect(img, bboxes)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# Now, we can get started with our image augmentations. The first one is **Horizontal Flipping**. The function takes one arguement, *p* which is the probability that the image will be flipped.

# %%
img_, bboxes_ = RandomHorizontalFlip(1)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Scaling**. Scales the image. If the argument *diff* is True, then the image is scaled with different values in the vertical and the horizontal directions, i.e. aspect ratio is not maintained.
#
# If the first argument is a float, then the scaling factors for both x and y directions are randomly sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomScale(0.3, diff = True)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Translation**. Translates the image. If the argument *diff* is True, then the image is translated with different values in the vertical and the horizontal directions.
#
# If the first argument is a float, then the translating factors for both x and y directions are randomly sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomTranslate(0.3, diff = True)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Rotation**. Rotates the image.
#
# If the first argument is a int, then the rotating angle, in degrees, is sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomRotate(10)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Shearing**. Sheares the image horizontally
#
# If the first argument is a float, then the shearing factor is sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomShear(0.2)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Resizing**.  Resizes the image to square dimensions while keeping the aspect ratio constant.
#
# The argument to this augmentation is the side of the square.

# %%
img_, bboxes_ = Resize(512)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# HSV transforms are supported as well.

# %%
img_, bboxes_ = RandomHSV(100, 100, 100)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# You can combine multiple transforms together by using the Sequence class as follows.

# %%
seq = Sequence([RandomHSV(40, 40, 30),RandomHorizontalFlip(), RandomScale(), RandomTranslate(), RandomRotate(10), RandomShear()])
img_, bboxes_ = seq(img.copy(), bboxes.copy())

plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# A list of all possible transforms can be found in the `docs` folder.

# %%
img = cv2.imread("person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
bboxes = parse_xml('person_1-0763.xml')

    
plotted_img = draw_rect(img, bboxes)
plt.imshow(plotted_img)
plt.show()

# %%
bboxes
# Out:
# array([[334., 302., 603., 512.]])

# %%
bboxes[0][1]
# Out:
# 302.0

# %%
def resize_image(img, bboxes, nome_arquivo, x, tamanho):
    img_, bboxes_ = Resize(tamanho)(img.copy(), bboxes.copy())
    novo_xml = '%s-augmentation%d-%d.xml' %  ( nome_arquivo, x, tamanho )
    novo_nome = '%s-augmentation%d-%d.jpg' % ( os.path.splitext(image_file)[0], x, tamanho )
    create_new_xml(xml_file, bboxes_[0], novo_xml, novo_nome)
    cv2.imwrite(novo_nome,img_[:,:,::-1])

# %%
for image_file in glob.glob(os.getcwd() + '/*.jpg'):
    
    
    img = cv2.imread(image_file)[:,:,::-1]    #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb   
    
    xml_file = os.path.splitext(image_file)[0] + '.xml'
    bboxes = parse_xml(xml_file)
    
    print(image_file)
    
    resize_image(img, bboxes, os.path.splitext(image_file)[0], 0, 128)
    resize_image(img, bboxes, os.path.splitext(image_file)[0], 0, 256)
    resize_image(img, bboxes, os.path.splitext(image_file)[0], 0, 512)
    
    for x in range(1, 11):  
        seq = Sequence([RandomHSV(100, 100, 100),RandomHorizontalFlip(), RandomScale(), RandomTranslate(), RandomRotate(10), RandomShear()])
        img_, bboxes_ = seq(img.copy(), bboxes.copy())
        
        nome_arquivo = os.path.splitext(image_file)[0]
        novo_nome = '%s-augmentation%d.jpg' % ( nome_arquivo, x )
        novo_xml = '%s-augmentation%d.xml' %  ( nome_arquivo, x )
        
        cv2.imwrite(novo_nome,img_[:,:,::-1])
        create_new_xml(xml_file, bboxes_[0], novo_xml, novo_nome)
        
        
        resize_image(img_, bboxes_, nome_arquivo, x, 128)
        resize_image(img_, bboxes_, nome_arquivo, x, 256)
        resize_image(img_, bboxes_, nome_arquivo, x, 512)
# Out:
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_1-0763.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_1-
jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0471.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0485.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0486.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0487.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0488.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0489.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0490.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0491.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0492.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0494.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0495.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0496.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0497.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0498.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0499.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0500.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0501.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0502.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0503.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0505.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0506.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0507.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0508.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0509.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0510.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0511.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0512.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0513.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0514.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0515.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0516.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0517.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0518.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0519.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0520.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0521.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0522.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0523.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0524.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0525.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0526.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0527.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0528.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0529.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0530.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0531.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0532.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0533.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0534.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0535.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0536.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0547.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0548.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0549.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0556.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0557.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0558.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0559.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0560.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0561.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0562.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0563.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0564.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0565.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0566.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0567.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0577.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0578.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0579.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0580.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0581.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0582.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0583.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0584.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0585.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0586.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0587.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0588.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0589.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0590.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0591.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0592.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0593.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0594.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0595.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0596.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0597.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0598.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0599.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0600.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0601.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0602.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0603.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0604.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0605.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0606.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0607.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0634.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0635.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0636.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0637.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0638.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0639.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0640.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0641.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0642.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0643.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0646.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0647.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0648.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0649.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0650.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0651.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0652.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0653.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0654.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0657.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0658.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0659.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0660.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0665.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0666.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0667.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0668.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0669.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0670.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0671.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0672.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0673.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0674.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0675.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0676.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0679.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0680.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0681.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0682.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0683.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0684.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0685.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0686.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0687.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0688.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0689.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0690.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0691.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0692.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0693.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0694.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0695.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0696.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0697.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0698.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0699.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0700.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0701.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0702.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0703.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0704.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0705.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0706.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0707.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0708.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0709.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0710.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0711.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0712.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0729.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0730.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0731.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0732.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0733.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0734.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0735.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0741.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0742.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0743.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0744.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0745.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0746.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0747.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0748.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0749.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0750.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0751.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0752.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0753.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0754.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0755.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0762.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0763.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0764.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0765.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0766.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0767.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0768.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0769.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0770.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0771.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0772.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0773.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0774.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0776.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0777.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0778.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0779.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0780.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0781.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0782.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0783.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0785.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0786.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0787.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0788.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0789.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0790.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0791.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0792.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0793.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0794.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0795.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0796.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0891.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0892.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0893.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0898.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0899.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0900.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0901.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0902.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0907.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0908.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0909.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0910.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0911.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0912.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_2-0913.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0217.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0218.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0219.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-c496ac460365> in <module>
#      15     for x in range(1, 11):
#      16         seq = Sequence([RandomHSV(100, 100, 100),RandomHorizontalFlip(), RandomScale(), RandomTranslate(), RandomRotate(10), RandomShear()])
# ---> 17         img_, bboxes_ = seq(img.copy(), bboxes.copy())
#      18
#      19         nome_arquivo = os.path.splitext(image_file)[0]
#
# ~\git\DataAugmentationForObjectDetection\data_aug\data_aug.py in __call__(self, images, bboxes)
#     853
#     854             if random.random() < prob:
# --> 855                 images, bboxes = augmentation(images, bboxes)
#     856         return images, bboxes
#
# ~\git\DataAugmentationForObjectDetection\data_aug\data_aug.py in __call__(self, img, bboxes)
#     456
#     457
# --> 458         corners[:,:8] = rotate_box(corners[:,:8], angle, cx, cy, h, w)
#     459
#     460         new_bbox = get_enclosing_box(corners)
#
# ~\git\DataAugmentationForObjectDetection\data_aug\bbox_util.py in rotate_box(corners, angle, cx, cy, h, w)
#     214
#     215     corners = corners.reshape(-1,2)
# --> 216     corners = np.hstack((corners, np.ones((corners.shape[0],1), dtype = type(corners[0][0]))))
#     217
#     218     M = cv2.getRotationMatrix2D((cx, cy), angle, 1.0)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
