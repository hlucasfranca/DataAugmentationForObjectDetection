# %% [markdown]
# # Data Augmentation For Object Detection
#
# This notebook serves as general manual to using this codebase. We cover all the major augmentations, as well as ways to combine them.

# %%
import xml.etree.ElementTree as ET
from data_aug.data_aug import *
from data_aug.bbox_util import *
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
import pickle as pkl
import glob
# %matplotlib inline

# %% [markdown]
# ## Storage Format
#
# First things first, we define how the storage formats required for images to work.
# 1. **The Image**: A OpenCV numpy array, of shape *(H x W x C)*.
# 2. **Annotations**: A numpy array of shape *N x 5* where *N* is the number of objects, one represented by each row. 5 columns represent the top-left x-coordinate, top-left y-coordinate, bottom-right x-coordinate, bottom-right y-coordinate, and the class of the object.
#
# Here is an image to aid your imagination.
#
# ![Annotation Format](ann_form.jpg)
#
# Whatever format your annotations are present in make sure, you convert them to this format.
#
# For demonstration purposes, we will be using the image above to show the transformations. The image as well as it's annotation has been provided. The annotation is a numpy array in a pickled format.

# %%
def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
        value = (root.find('filename').text,
                 int(root.find('size')[0].text),
                 int(root.find('size')[1].text),
                 member[0].text,
                 int(member[4][0].text),
                 int(member[4][1].text),
                 int(member[4][2].text),
                 int(member[4][3].text)
                 )
        arr = [float(member[4][0].text), float(member[4][1].text), float(member[4][2].text), float(member[4][3].text)]
        
    return np.array([arr])

# %%
def create_new_xml(xml_file, arr, new_xml, novo_nome):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
        value = (root.find('filename').text,
                 int(root.find('size')[0].text),
                 int(root.find('size')[1].text),
                 member[0].text,
                 int(member[4][0].text),
                 int(member[4][1].text),
                 int(member[4][2].text),
                 int(member[4][3].text)
                 )
        root.find('filename').text = novo_nome
        root.find('path').text = novo_nome
        member[4][0].text = str(int(arr[0]))
        member[4][1].text = str(int(arr[1]))
        member[4][2].text = str(int(arr[2]))
        member[4][3].text = str(int(arr[3]) )     
        
    tree.write(new_xml)

# %%
img = cv2.imread("imagens/person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
bboxes = parse_xml('imagens/person_1-0763.xml')

#inspect the bounding boxes
print(bboxes)
# Out:
# [[334. 302. 603. 512.]]

# %%
bboxes
# Out:
# array([[334., 302., 603., 512.]])

# %% [markdown]
# You can use the function `draw_rect` to plot the bounding boxes on an image.

# %%
plotted_img = draw_rect(img, bboxes)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# Now, we can get started with our image augmentations. The first one is **Horizontal Flipping**. The function takes one arguement, *p* which is the probability that the image will be flipped.

# %%
img_, bboxes_ = RandomHorizontalFlip(1)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Scaling**. Scales the image. If the argument *diff* is True, then the image is scaled with different values in the vertical and the horizontal directions, i.e. aspect ratio is not maintained.
#
# If the first argument is a float, then the scaling factors for both x and y directions are randomly sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomScale(0.3, diff = True)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Translation**. Translates the image. If the argument *diff* is True, then the image is translated with different values in the vertical and the horizontal directions.
#
# If the first argument is a float, then the translating factors for both x and y directions are randomly sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomTranslate(0.3, diff = True)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Rotation**. Rotates the image.
#
# If the first argument is a int, then the rotating angle, in degrees, is sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomRotate(10)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Shearing**. Sheares the image horizontally
#
# If the first argument is a float, then the shearing factor is sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomShear(0.2)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Resizing**.  Resizes the image to square dimensions while keeping the aspect ratio constant.
#
# The argument to this augmentation is the side of the square.

# %%
img_, bboxes_ = Resize(64)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# HSV transforms are supported as well.

# %%
img_, bboxes_ = RandomHSV(100, 100, 100)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# You can combine multiple transforms together by using the Sequence class as follows.

# %%
seq = Sequence([RandomHSV(40, 40, 30),RandomHorizontalFlip(), RandomScale(), RandomTranslate(), RandomRotate(10), RandomShear()])
img_, bboxes_ = seq(img.copy(), bboxes.copy())

plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# A list of all possible transforms can be found in the `docs` folder.

# %%
img = cv2.imread("imagens/person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
bboxes = parse_xml('imagens/person_1-0763.xml')

    
plotted_img = draw_rect(img, bboxes)
plt.imshow(plotted_img)
plt.show()

# %%
bboxes
# Out:
# array([[334., 302., 603., 512.]])

# %%
bboxes[0][1]
# Out:
# 302.0

# %%
def resize_image(img, bboxes, nome_arquivo, x, tamanho):
    img_, bboxes_ = Resize(tamanho)(img.copy(), bboxes.copy())
    
    novo_xml = 'imagens/dataset/%s-augmentation%d-%d.xml' %  ( nome_arquivo, x, tamanho )
    novo_nome = 'imagens/dataset/%s-augmentation%d-%d.jpg' % ( nome_arquivo, x, tamanho )
    
    create_new_xml(xml_file, bboxes_[0], novo_xml, novo_nome)
    cv2.imwrite(novo_nome,img_[:,:,::-1])
    
    print(novo_xml)
    print(novo_nome)

def gerar_transformacao_aleatoria(img, bboxes, nome_arquivo, x, tamanho):
    img_, bboxes_ = Resize(tamanho)(img.copy(), bboxes.copy())
    
    seq = Sequence([RandomHSV(100, 100, 100), RandomScale(), RandomTranslate(), RandomRotate(10), RandomShear()])
    img_, bboxes_ = seq(img_.copy(), bboxes_.copy())
    
    novo_xml = 'imagens/dataset/%s-augmentation%d-%d.xml' %  ( nome_arquivo, x, tamanho )
    novo_nome = 'imagens/dataset/%s-augmentation%d-%d.jpg' % ( nome_arquivo, x, tamanho )

    create_new_xml(xml_file, bboxes_[0], novo_xml, novo_nome)
    
    cv2.imwrite(novo_nome,img_[:,:,::-1])

# %%
for image_file in glob.glob(os.getcwd() + '/imagens/*.jpg'):
    dimensoes = [128,256,512]
    
    nome = os.path.splitext(os.path.basename(image_file))[0]
    xml_file = 'imagens/%s.xml' % (nome)
    
    #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb   
    img = cv2.imread(image_file)[:,:,::-1]    
    bboxes = parse_xml(xml_file)
    
    print(nome)
    
    for dimensao in dimensoes:
        resize_image(img, bboxes, nome, 0, dimensao)
        
        for x in range(2):
            gerar_transformacao_aleatoria(img, bboxes, nome, x, dimensao)
# Out:
# person_1-0763
# imagens/dataset/person_1-0763-augmentation0-128.xml
# imagens/dataset/person_1-0763-augmentation0-128.jpg
# imagens/dataset/person_1-0763-augmentation0-128.xml
# imagens/dataset/person_1-0763-augmentation0-128.jpg
# imagens/dataset/person_1-0763-augmentation1-128.xml
# imagens/dataset/person_1-0763-augmentation1-128.jpg
# imagens/dataset/person_1-0763-augmentation0-256.xml
# imagens/dataset/person_1-0763-augmentation0-256.jpg
# imagens/dataset/person_1-0763-augmentation0-256.xml
# imagens/dataset/person_1-0763-augmentation0-256.jpg
# imagens/dataset/person_1-0763-augmentation1-256.xml
# imagens/dataset/person_1-0763-augmentation1-256.jpg
# imagens/dataset/person_1-0763-augmentation0-512.xml
# imagens/dataset/person_1-0763-augmentation0-512.jpg
# imagens/dataset/person_1-0763-augmentation0-512.xml
# imagens/dataset/person_1-0763-augmentation0-512.jpg
# imagens/dataset/person_1-0763-augmentation1-512.xml
# imagens/dataset/person_1-0763-augmentation1-512.jpg
# person_1-0764
# imagens/dataset/person_1-0764-augmentation0-128.xml
# imagens/dataset/person_1-0764-augmentation0-128.jpg
# imagens/dataset/person_1-0764-augmentation0-128.xml
# imagens/dataset/person_1-0764-augmentation0-128.jpg
# imagens/dataset/person_1-0764-augmentation1-128.xml
# imagens/dataset/person_1-0764-augmentation1-128.jpg
# imagens/dataset/person_1-0764-augmentation0-256.xml
# imagens/dataset/person_1-0764-augmentation0-256.jpg
# imagens/dataset/person_1-0764-augmentation0-256.xml
# imagens/dataset/person_1-0764-augmentation0-256.jpg
# imagens/dataset/person_1-0764-augmentation1-256.xml
# imagens/dataset/person_1-0764-augmentation1-256.jpg
# imagens/dataset/person_1-0764-augmentation0-512.xml
# imagens/dataset/person_1-0764-augmentation0-512.jpg
# imagens/dataset/person_1-0764-augmentation0-512.xml
# imagens/dataset/person_1-0764-augmentation0-512.jpg
# imagens/dataset/person_1-0764-augmentation1-512.xml
# imagens/dataset/person_1-0764-augmentation1-512.jpg
# person_1-0765
# imagens/dataset/person_1-0765-augmentation0-128.xml
# imagens/dataset/person_1-0765-augmentation0-128.jpg
# imagens/dataset/person_1-0765-augmentation0-128.xml
# imagens/dataset/person_1-0765-augmentation0-128.jpg
# imagens/dataset/person_1-0765-augmentation1-128.xml
# imagens/dataset/person_1-0765-augmentation1-128.jpg
# imagens/dataset/person_1-0765-augmentation0-256.xml
# imagens/dataset/person_1-0765-augmentation0-256.jpg
# imagens/dataset/person_1-0765-augmentation0-256.xml
# imagens/dataset/person_1-0765-augmentation0-256.jpg
# imagens/dataset/person_1-0765-augmentation1-256.xml
# imagens/dataset/person_1-0765-augmentation1-256.jpg
# imagens/dataset/person_1-0765-augmentation0-512.xml
# imagens/dataset/person_1-0765-augmentation0-512.jpg
# imagens/dataset/person_1-0765-augmentation0-512.xml
# imagens/dataset/person_1-0765-augmentation0-512.jpg
# imagens/dataset/person_1-0765-augmentation1-512.xml
# imagens/dataset/person_1-0765-augmentation1-512.jpg
# person_1-0766
# imagens/dataset/person_1-0766-augmentation0-128.xml
# imagens/dataset/person_1-0766-augmentation0-128.jpg
# imagens/dataset/person_1-0766-augmentation0-128.xml
# imagens/dataset/person_1-0766-augmentation0-128.jpg
# imagens/dataset/person_1-0766-augmentation1-128.xml
# imagens/dataset/person_1-0766-augmentation1-128.jpg
# imagens/dataset/person_1-0766-augmentation0-256.xml
# imagens/dataset/person_1-0766-augmentation0-256.jpg
# imagens/dataset/person_1-0766-augmentation0-256.xml
# imagens/dataset/person_1-0766-augmentation0-256.jpg
# imagens/dataset/person_1-0766-augmentation1-256.xml
# imagens/dataset/person_1-0766-augmentation1-256.jpg
# imagens/dataset/person_1-0766-augmentation0-512.xml
# imagens/dataset/person_1-0766-augmentation0-512.jpg
# imagens/dataset/person_1-0766-augmentation0-512.xml
# imagens/dataset/person_1-0766-augmentation0-512.jpg
# imagens/dataset/person_1-0766-augmentation1-512.xml
# imagens/dataset/person_1-0766-augmentation1-512.jpg
# person_1-0767
# imagens/dataset/person_1-0767-augmentation0-128.xml
# imagens/dataset/person_1-0767-augmentation0-128.jpg
# imagens/dataset/person_1-0767-augmentation0-128.xml
# imagens/dataset/person_1-0767-augmentation0-128.jpg
# imagens/dataset/person_1-0767-augmentation1-128.xml
# imagens/dataset/person_1-0767-augmentation1-128.jpg
# imagens/dataset/person_1-0767-augmentation0-256.xml
# imagens/dataset/person_1-0767-augmentation0-256.jpg
# imagens/dataset/person_1-0767-augmentation0-256.xml
# imagens/dataset/person_1-0767-augmentation0-256.jpg
# imagens/dataset/person_1-0767-augmentation1-256.xml
# imagens/dataset/person_1-0767-augmentation1-256.jpg
# imagens/dataset/person_1-0767-augmentation0-512.xml
# imagens/dataset/person_1-0767-augmentation0-512.jpg
# imagens/dataset/person_1-0767-augmentation0-512.xml
# imagens/dataset/person_1-0767-augmentation0-512.jpg
# imagens/dataset/person_1-0767-augmentation1-512.xml
# imagens/dataset/person_1-0767-augmentation1-512.jpg
# person_1-0768
# imagens/dataset/person_1-0768-augmentation0-128.xml
# imagens/dataset/person_1-0768-augmentation0-128.jpg
# imagens/dataset/person_1-0768-augmentation0-128.xml
# imagens/dataset/person_1-0768-augmentation0-128.jpg
# imagens/dataset/person_1-0768-augmentation1-128.xml
# imagens/dataset/person_1-0768-augmentation1-128.jpg
# imagens/dataset/person_1-0768-augmentation0-256.xml
# imagens/dataset/person_1-0768-augmentation0-256.jpg
# imagens/dataset/person_1-0768-augmentation0-256.xml
# imagens/dataset/person_1-0768-augmentation0-256.jpg
# imagens/dataset/person_1-0768-augmentation1-256.xml
# imagens/dataset/person_1-0768-augmentation1-256.jpg
# imagens/dataset/person_1-0768-augmentation0-512.xml
# imagens/dataset/person_1-0768-augmentation0-512.jpg
# imagens/dataset/person_1-0768-augmentation0-512.xml
# imagens/dataset/person_1-0768-augmentation0-512.jpg
# imagens/dataset/person_1-0768-augmentation1-512.xml
# imagens/dataset/person_1-0768-augmentation1-512.jpg
# person_1-0769
# imagens/dataset/person_1-0769-augmentation0-128.xml
# imagens/dataset/person_1-0769-augmentation0-128.jpg
# imagens/dataset/person_1-0769-augmentation0-128.xml
# imagens/dataset/person_1-0769-augmentation0-128.jpg
# imagens/dataset/person_1-0769-augmentation1-128.xml
# imagens/dataset/person_1-0769-augmentation1-128.jpg
# imagens/dataset/person_1-0769-augmentation0-256.xml
# imagens/dataset/person_1-0769-augmentation0-256.jpg
# imagens/dataset/person_1-0769-augmentation0-256.xml
# imagens/dataset/person_1-0769-augmentation0-256.jpg
# imagens/dataset/person_1-0769-augmentation1-256.xml
# imagens/dataset/person_1-0769-augmentation1-256.jpg
# imagens/dataset/person_1-0769-augmentation0-512.xml
# imagens/dataset/person_1-0769-augmentation0-512.jpg
# imagens/dataset/person_1-0769-augmentation0-512.xml
# imagens/dataset/person_1-0769-augmentation0-512.jpg
# imagens/dataset/person_1-0769-augmentation1-512.xml
# imagens/dataset/person_1-0769-augmentation1-512.jpg
# person_1-0770
# imagens/dataset/person_1-0770-augmentation0-128.xml
# imagens/dataset/person_1-0770-augmentation0-128.jpg
# imagens/dataset/person_1-0770-augmentation0-128.xml
# imagens/dataset/person_1-0770-augmentation0-128.jpg
# imagens/dataset/person_1-0770-augmentation1-128.xml
# imagens/dataset/person_1-0770-augmentation1-128.jpg
# imagens/dataset/person_1-0770-augmentation0-256.xml
# imagens/dataset/person_1-0770-augmentation0-256.jpg
# imagens/dataset/person_1-0770-augmentation0-256.xml
# imagens/dataset/person_1-0770-augmentation0-256.jpg
# imagens/dataset/person_1-0770-augmentation1-256.xml
# imagens/dataset/person_1-0770-augmentation1-256.jpg
# imagens/dataset/person_1-0770-augmentation0-512.xml
# imagens/dataset/person_1-0770-augmentation0-512.jpg
# imagens/dataset/person_1-0770-augmentation0-512.xml
# imagens/dataset/person_1-0770-augmentation0-512.jpg
# imagens/dataset/person_1-0770-augmentation1-512.xml
# imagens/dataset/person_1-0770-augmentation1-512.jpg
# person_1-0771
# imagens/dataset/person_1-0771-augmentation0-128.xml
# imagens/dataset/person_1-0771-augmentation0-128.jpg
# imagens/dataset/person_1-0771-augmentation0-128.xml
# imagens/dataset/person_1-0771-augmentation0-128.jpg
# imagens/dataset/person_1-0771-augmentation1-128.xml
# imagens/dataset/person_1-0771-augmentation1-128.jpg
# imagens/dataset/person_1-0771-augmentation0-256.xml
# imagens/dataset/person_1-0771-augmentation0-256.jpg
# imagens/dataset/person_1-0771-augmentation0-256.xml
# imagens/dataset/person_1-0771-augmentation0-256.jpg
# imagens/dataset/person_1-0771-augmentation1-256.xml
# imagens/dataset/person_1-0771-augmentation1-256.jpg
# imagens/dataset/person_1-0771-augmentation0-512.xml
# imagens/dataset/person_1-0771-augmentation0-512.jpg
# imagens/dataset/person_1-0771-augmentation0-512.xml
# imagens/dataset/person_1-0771-augmentation0-512.jpg
# imagens/dataset/person_1-0771-augmentation1-512.xml
# imagens/dataset/person_1-0771-augmentation1-512.jpg
# person_1-0772
# imagens/dataset/person_1-0772-augmentation0-128.xml
# imagens/dataset/person_1-0772-augmentation0-128.jpg
# imagens/dataset/person_1-0772-augmentation0-128.xml
# imagens/dataset/person_1-0772-augmentation0-128.jpg
# imagens/dataset/person_1-0772-augmentation1-128.xml
# imagens/dataset/person_1-0772-augmentation1-128.jpg
# imagens/dataset/person_1-0772-augmentation0-256.xml
# imagens/dataset/person_1-0772-augmentation0-256.jpg
# imagens/dataset/person_1-0772-augmentation0-256.xml
# imagens/dataset/person_1-0772-augmentation0-256.jpg
# imagens/dataset/person_1-0772-augmentation1-256.xml
# imagens/dataset/person_1-0772-augmentation1-256.jpg
# imagens/dataset/person_1-0772-augmentation0-512.xml
# imagens/dataset/person_1-0772-augmentation0-512.jpg
# imagens/dataset/person_1-0772-augmentation0-512.xml
# imagens/dataset/person_1-0772-augmentation0-512.jpg
# imagens/dataset/person_1-0772-augmentation1-512.xml
# imagens/dataset/person_1-0772-augmentation1-512.jpg
# person_1-0778
# imagens/dataset/person_1-0778-augmentation0-128.xml
# imagens/dataset/person_1-0778-augmentation0-128.jpg
# imagens/dataset/person_1-0778-augmentation0-128.xml
# imagens/dataset/person_1-0778-augmentation0-128.jpg
# imagens/dataset/person_1-0778-augmentation1-128.xml
# imagens/dataset/person_1-0778-augmentation1-128.jpg
# imagens/dataset/person_1-0778-augmentation0-256.xml
# imagens/dataset/person_1-0778-augmentation0-256.jpg
# imagens/dataset/person_1-0778-augmentation0-256.xml
# imagens/dataset/person_1-0778-augmentation0-256.jpg
# imagens/dataset/person_1-0778-augmentation1-256.xml
# imagens/dataset/person_1-0778-augmentation1-256.jpg
# imagens/dataset/person_1-0778-augmentation0-512.xml
# imagens/dataset/person_1-0778-augmentation0-512.jpg
# imagens/dataset/person_1-0778-augmentation0-512.xml
# imagens/dataset/person_1-0778-augmentation0-512.jpg
# imagens/dataset/person_1-0778-augmentation1-512.xml
# imagens/dataset/person_1-0778-augmentation1-512.jpg
# person_1-0779
# imagens/dataset/person_1-0779-augmentation0-128.xml
# imagens/dataset/person_1-0779-augmentation0-128.jpg
# imagens/dataset/person_1-0779-augmentation0-128.xml
# imagens/dataset/person_1-0779-augmentation0-128.jpg
# imagens/dataset/person_1-0779-augmentation1-128.xml
# imagens/dataset/person_1-0779-augmentation1-128.jpg
# imagens/dataset/person_1-0779-augmentation0-256.xml
# imagens/dataset/person_1-0779-augmentation0-256.jpg
# imagens/dataset/person_1-0779-augmentation0-256.xml
# imagens/dataset/person_1-0779-augmentation0-256.jpg
# imagens/dataset/person_1-0779-augmentation1-256.xml
# imagens/dataset/person_1-0779-augmentation1-256.jpg
# imagens/dataset/person_1-0779-augmentation0-512.xml
# imagens/dataset/person_1-0779-augmentation0-512.jpg
# imagens/dataset/person_1-0779-augmentation0-512.xml
# imagens/dataset/person_1-0779-augmentation0-512.jpg
# imagens/dataset/person_1-0779-augmentation1-512.xml
# imagens/dataset/person_1-0779-augmentation1-512.jpg
# person_1-0780
# imagens/dataset/person_1-0780-augmentation0-128.xml
# imagens/dataset/person_1-0780-augmentation0-128.jpg
# imagens/dataset/person_1-0780-augmentation0-128.xml
# imagens/dataset/person_1-0783-augmentation1-128.xml
# imagens/dataset/person_1-0783-augmentation1-128.jpg
# imagens/dataset/person_1-0783-augmentation0-256.xml
# imagens/dataset/person_1-0783-augmentation0-256.jpg
# imagens/dataset/person_1-0783-augmentation0-256.xml
# imagens/dataset/person_1-0783-augmentation0-256.jpg
# imagens/dataset/person_1-0783-augmentation1-256.xml
# imagens/dataset/person_1-0783-augmentation1-256.jpg
# imagens/dataset/person_1-0783-augmentation0-512.xml
# imagens/dataset/person_1-0783-augmentation0-512.jpg
# imagens/dataset/person_1-0783-augmentation0-512.xml
# imagens/dataset/person_1-0783-augmentation0-512.jpg
# imagens/dataset/person_1-0783-augmentation1-512.xml
# imagens/dataset/person_1-0783-augmentation1-512.jpg
# person_1-0784
# imagens/dataset/person_1-0784-augmentation0-128.xml
# imagens/dataset/person_1-0784-augmentation0-128.jpg
# imagens/dataset/person_1-0784-augmentation0-128.xml
# imagens/dataset/person_1-0784-augmentation0-128.jpg
# imagens/dataset/person_1-0784-augmentation1-128.xml
# imagens/dataset/person_1-0784-augmentation1-128.jpg
# imagens/dataset/person_1-0784-augmentation0-256.xml
# imagens/dataset/person_1-0784-augmentation0-256.jpg
# imagens/dataset/person_1-0784-augmentation0-256.xml
# imagens/dataset/person_1-0784-augmentation0-256.jpg
# imagens/dataset/person_1-0784-augmentation1-256.xml
# imagens/dataset/person_1-0784-augmentation1-256.jpg
# imagens/dataset/person_1-0784-augmentation0-512.xml
# imagens/dataset/person_1-0784-augmentation0-512.jpg
# imagens/dataset/person_1-0784-augmentation0-512.xml
# imagens/dataset/person_1-0784-augmentation0-512.jpg
# imagens/dataset/person_1-0784-augmentation1-512.xml
# imagens/dataset/person_1-0784-augmentation1-512.jpg
# person_1-0785
# imagens/dataset/person_1-0785-augmentation0-128.xml
# imagens/dataset/person_1-0785-augmentation0-128.jpg
# imagens/dataset/person_1-0785-augmentation0-128.xml
# imagens/dataset/person_1-0785-augmentation0-128.jpg
# imagens/dataset/person_1-0785-augmentation1-128.xml
# imagens/dataset/person_1-0785-augmentation1-128.jpg
# imagens/dataset/person_1-0785-augmentation0-256.xml
# imagens/dataset/person_1-0785-augmentation0-256.jpg
# imagens/dataset/person_1-0785-augmentation0-256.xml
# imagens/dataset/person_1-0785-augmentation0-256.jpg
# imagens/dataset/person_1-0785-augmentation1-256.xml
# imagens/dataset/person_1-0785-augmentation1-256.jpg
# imagens/dataset/person_1-0785-augmentation0-512.xml
# imagens/dataset/person_1-0785-augmentation0-512.jpg
# imagens/dataset/person_1-0785-augmentation0-512.xml
# imagens/dataset/person_1-0785-augmentation0-512.jpg
# imagens/dataset/person_1-0785-augmentation1-512.xml
# imagens/dataset/person_1-0785-augmentation1-512.jpg
# person_1-0786
# imagens/dataset/person_1-0786-augmentation0-128.xml
# imagens/dataset/person_1-0786-augmentation0-128.jpg
# imagens/dataset/person_1-0786-augmentation0-128.xml
# imagens/dataset/person_1-0786-augmentation0-128.jpg
# imagens/dataset/person_1-0786-augmentation1-128.xml
# imagens/dataset/person_1-0804-augmentation0-256.jpg
# imagens/dataset/person_1-0804-augmentation1-256.xml
# imagens/dataset/person_1-0804-augmentation1-256.jpg
# imagens/dataset/person_1-0804-augmentation0-512.xml
# imagens/dataset/person_1-0804-augmentation0-512.jpg
# imagens/dataset/person_1-0804-augmentation0-512.xml
# imagens/dataset/person_1-0804-augmentation0-512.jpg
# imagens/dataset/person_1-0804-augmentation1-512.xml
# imagens/dataset/person_1-0804-augmentation1-512.jpg
# person_1-0805
# imagens/dataset/person_1-0805-augmentation0-128.xml
# imagens/dataset/person_1-0805-augmentation0-128.jpg
# imagens/dataset/person_1-0805-augmentation0-128.xml
# imagens/dataset/person_1-0805-augmentation0-128.jpg
# imagens/dataset/person_1-0805-augmentation1-128.xml
# imagens/dataset/person_1-0805-augmentation1-128.jpg
# imagens/dataset/person_1-0805-augmentation0-256.xml
# imagens/dataset/person_1-0805-augmentation0-256.jpg
# imagens/dataset/person_1-0805-augmentation0-256.xml
# imagens/dataset/person_1-0805-augmentation0-256.jpg
# imagens/dataset/person_1-0805-augmentation1-256.xml
# imagens/dataset/person_1-0805-augmentation1-256.jpg
# imagens/dataset/person_1-0805-augmentation0-512.xml
# imagens/dataset/person_1-0805-augmentation0-512.jpg
# imagens/dataset/person_1-0805-augmentation0-512.xml
# imagens/dataset/person_1-0805-augmentation0-512.jpg
# imagens/dataset/person_1-0805-augmentation1-512.xml
# imagens/dataset/person_1-0805-augmentation1-512.jpg
# person_1-0806
# imagens/dataset/person_1-0806-augmentation0-128.xml
# imagens/dataset/person_1-0806-augmentation0-128.jpg
# imagens/dataset/person_1-0806-augmentation0-128.xml
# imagens/dataset/person_1-0806-augmentation0-128.jpg
# imagens/dataset/person_1-0806-augmentation1-128.xml
# imagens/dataset/person_1-0806-augmentation1-128.jpg
# imagens/dataset/person_1-0806-augmentation0-256.xml
# imagens/dataset/person_1-0806-augmentation0-256.jpg
# imagens/dataset/person_1-0806-augmentation0-256.xml
# imagens/dataset/person_1-0806-augmentation0-256.jpg
# imagens/dataset/person_1-0806-augmentation1-256.xml
# imagens/dataset/person_1-0806-augmentation1-256.jpg
# imagens/dataset/person_1-0806-augmentation0-512.xml
# imagens/dataset/person_1-0806-augmentation0-512.jpg
# imagens/dataset/person_1-0806-augmentation0-512.xml
# imagens/dataset/person_1-0806-augmentation0-512.jpg
# imagens/dataset/person_1-0806-augmentation1-512.xml
# imagens/dataset/person_1-0806-augmentation1-512.jpg
# person_1-0807
# imagens/dataset/person_1-0807-augmentation0-128.xml
# imagens/dataset/person_1-0807-augmentation0-128.jpg
# imagens/dataset/person_1-0807-augmentation0-128.xml
# imagens/dataset/person_1-0807-augmentation0-128.jpg
# imagens/dataset/person_1-0807-augmentation1-128.xml
# imagens/dataset/person_1-0807-augmentation1-128.jpg
# imagens/dataset/person_1-0807-augmentation0-256.xml
# imagens/dataset/person_1-0807-augmentation0-256.jpg
# imagens/dataset/person_1-0807-augmentation0-256.xml
# imagens/dataset/person_1-0807-augmentation0-256.jpg
# imagens/dataset/person_1-0811-augmentation1-256.jpg
# imagens/dataset/person_1-0811-augmentation0-512.xml
# imagens/dataset/person_1-0811-augmentation0-512.jpg
# imagens/dataset/person_1-0811-augmentation0-512.xml
# imagens/dataset/person_1-0811-augmentation0-512.jpg
# imagens/dataset/person_1-0811-augmentation1-512.xml
# imagens/dataset/person_1-0811-augmentation1-512.jpg
# person_1-0812
# imagens/dataset/person_1-0812-augmentation0-128.xml
# imagens/dataset/person_1-0812-augmentation0-128.jpg
# imagens/dataset/person_1-0812-augmentation0-128.xml
# imagens/dataset/person_1-0812-augmentation0-128.jpg
# imagens/dataset/person_1-0812-augmentation1-128.xml
# imagens/dataset/person_1-0812-augmentation1-128.jpg
# imagens/dataset/person_1-0812-augmentation0-256.xml
# imagens/dataset/person_1-0812-augmentation0-256.jpg
# imagens/dataset/person_1-0812-augmentation0-256.xml
# imagens/dataset/person_1-0812-augmentation0-256.jpg
# imagens/dataset/person_1-0812-augmentation1-256.xml
# imagens/dataset/person_1-0812-augmentation1-256.jpg
# imagens/dataset/person_1-0812-augmentation0-512.xml
# imagens/dataset/person_1-0812-augmentation0-512.jpg
# imagens/dataset/person_1-0812-augmentation0-512.xml
# imagens/dataset/person_1-0812-augmentation0-512.jpg
# imagens/dataset/person_1-0812-augmentation1-512.xml
# imagens/dataset/person_1-0812-augmentation1-512.jpg
# person_1-0813
# imagens/dataset/person_1-0813-augmentation0-128.xml
# imagens/dataset/person_1-0813-augmentation0-128.jpg
# imagens/dataset/person_1-0813-augmentation0-128.xml
# imagens/dataset/person_1-0813-augmentation0-128.jpg
# imagens/dataset/person_1-0813-augmentation1-128.xml
# imagens/dataset/person_1-0813-augmentation1-128.jpg
# imagens/dataset/person_1-0813-augmentation0-256.xml
# imagens/dataset/person_1-0813-augmentation0-256.jpg
# imagens/dataset/person_1-0813-augmentation0-256.xml
# imagens/dataset/person_1-0813-augmentation0-256.jpg
# imagens/dataset/person_1-0813-augmentation1-256.xml
# imagens/dataset/person_1-0813-augmentation1-256.jpg
# imagens/dataset/person_1-0813-augmentation0-512.xml
# imagens/dataset/person_1-0813-augmentation0-512.jpg
# imagens/dataset/person_1-0813-augmentation0-512.xml
# imagens/dataset/person_1-0813-augmentation0-512.jpg
# imagens/dataset/person_1-0813-augmentation1-512.xml
# imagens/dataset/person_1-0813-augmentation1-512.jpg
# person_1-0814
# imagens/dataset/person_1-0814-augmentation0-128.xml
# imagens/dataset/person_1-0814-augmentation0-128.jpg
# imagens/dataset/person_1-0814-augmentation0-128.xml
# imagens/dataset/person_1-0814-augmentation0-128.jpg
# imagens/dataset/person_1-0814-augmentation1-128.xml
# imagens/dataset/person_1-0814-augmentation1-128.jpg
# imagens/dataset/person_1-0814-augmentation0-256.xml
# imagens/dataset/person_1-0814-augmentation0-256.jpg
# imagens/dataset/person_1-0814-augmentation0-256.xml
# imagens/dataset/person_1-0814-augmentation0-256.jpg
# imagens/dataset/person_1-0814-augmentation1-256.xml
# imagens/dataset/person_1-0814-augmentation1-256.jpg
# imagens/dataset/person_1-0829-augmentation0-512.jpg
# imagens/dataset/person_1-0829-augmentation1-512.xml
# imagens/dataset/person_1-0829-augmentation1-512.jpg
# person_1-0830
# imagens/dataset/person_1-0830-augmentation0-128.xml
# imagens/dataset/person_1-0830-augmentation0-128.jpg
# imagens/dataset/person_1-0830-augmentation0-128.xml
# imagens/dataset/person_1-0830-augmentation0-128.jpg
# imagens/dataset/person_1-0830-augmentation1-128.xml
# imagens/dataset/person_1-0830-augmentation1-128.jpg
# imagens/dataset/person_1-0830-augmentation0-256.xml
# imagens/dataset/person_1-0830-augmentation0-256.jpg
# imagens/dataset/person_1-0830-augmentation0-256.xml
# imagens/dataset/person_1-0830-augmentation0-256.jpg
# imagens/dataset/person_1-0830-augmentation1-256.xml
# imagens/dataset/person_1-0830-augmentation1-256.jpg
# imagens/dataset/person_1-0830-augmentation0-512.xml
# imagens/dataset/person_1-0830-augmentation0-512.jpg
# imagens/dataset/person_1-0830-augmentation0-512.xml
# imagens/dataset/person_1-0830-augmentation0-512.jpg
# imagens/dataset/person_1-0830-augmentation1-512.xml
# imagens/dataset/person_1-0830-augmentation1-512.jpg
# person_1-0831
# imagens/dataset/person_1-0831-augmentation0-128.xml
# imagens/dataset/person_1-0831-augmentation0-128.jpg
# imagens/dataset/person_1-0831-augmentation0-128.xml
# imagens/dataset/person_1-0831-augmentation0-128.jpg
# imagens/dataset/person_1-0831-augmentation1-128.xml
# imagens/dataset/person_1-0831-augmentation1-128.jpg
# imagens/dataset/person_1-0831-augmentation0-256.xml
# imagens/dataset/person_1-0831-augmentation0-256.jpg
# imagens/dataset/person_1-0831-augmentation0-256.xml
# ...
# person_1-0872
# imagens/dataset/person_1-0872-augmentation0-128.xml
# imagens/dataset/person_1-0872-augmentation0-128.jpg
# imagens/dataset/person_1-0872-augmentation0-128.xml
# imagens/dataset/person_1-0872-augmentation0-128.jpg
# imagens/dataset/person_1-0872-augmentation1-128.xml
# imagens/dataset/person_1-0872-augmentation1-128.jpg
# imagens/dataset/person_1-0872-augmentation0-256.xml
# imagens/dataset/person_1-0872-augmentation0-256.jpg
# imagens/dataset/person_1-0872-augmentation0-256.xml
# imagens/dataset/person_1-0872-augmentation0-256.jpg
# imagens/dataset/person_1-0872-augmentation1-256.xml
# imagens/dataset/person_1-0872-augmentation1-256.jpg
# imagens/dataset/person_1-0872-augmentation0-512.xml
# imagens/dataset/person_1-0872-augmentation0-512.jpg
# imagens/dataset/person_1-0872-augmentation0-512.xml
# imagens/dataset/person_1-0872-augmentation0-512.jpg
# imagens/dataset/person_1-0872-augmentation1-512.xml
# imagens/dataset/person_1-0872-augmentation1-512.jpg
# person_1-0876
# imagens/dataset/person_1-0876-augmentation0-128.xml
# imagens/dataset/person_1-0876-augmentation0-128.jpg
# imagens/dataset/person_1-0876-augmentation0-128.xml
# imagens/dataset/person_1-0876-augmentation0-128.jpg
# imagens/dataset/person_1-0876-augmentation1-128.xml
# imagens/dataset/person_1-0876-augmentation1-128.jpg
# imagens/dataset/person_1-0876-augmentation0-256.xml
# imagens/dataset/person_1-0876-augmentation0-256.jpg
# imagens/dataset/person_1-0876-augmentation0-256.xml
# imagens/dataset/person_1-0876-augmentation0-256.jpg
# imagens/dataset/person_1-0876-augmentation1-256.xml
# imagens/dataset/person_1-0876-augmentation1-256.jpg
# imagens/dataset/person_1-0876-augmentation0-512.xml
# imagens/dataset/person_1-0876-augmentation0-512.jpg
# imagens/dataset/person_1-0876-augmentation0-512.xml
# imagens/dataset/person_1-0876-augmentation0-512.jpg
# imagens/dataset/person_1-0876-augmentation1-512.xml
# imagens/dataset/person_1-0876-augmentation1-512.jpg
# person_1-0877
# imagens/dataset/person_1-0877-augmentation0-128.xml
# imagens/dataset/person_1-0877-augmentation0-128.jpg
# imagens/dataset/person_1-0877-augmentation0-128.xml
# imagens/dataset/person_1-0877-augmentation0-128.jpg
# imagens/dataset/person_1-0877-augmentation1-128.xml
# imagens/dataset/person_1-0877-augmentation1-128.jpg
# imagens/dataset/person_1-0877-augmentation0-256.xml
# imagens/dataset/person_1-0877-augmentation0-256.jpg
# imagens/dataset/person_1-0877-augmentation0-256.xml
# imagens/dataset/person_1-0877-augmentation0-256.jpg
# imagens/dataset/person_1-0877-augmentation1-256.xml
# imagens/dataset/person_1-0877-augmentation1-256.jpg
# imagens/dataset/person_1-0877-augmentation0-512.xml
# imagens/dataset/person_1-0877-augmentation0-512.jpg
# imagens/dataset/person_1-0877-augmentation0-512.xml
# imagens/dataset/person_1-0877-augmentation0-512.jpg
# imagens/dataset/person_1-0877-augmentation1-512.xml
# imagens/dataset/person_1-0877-augmentation1-512.jpg
# person_1-0878
# imagens/dataset/person_1-0878-augmentation0-128.xml
# imagens/dataset/person_1-0878-augmentation0-128.jpg
# imagens/dataset/person_1-0878-augmentation0-128.xml
# imagens/dataset/person_1-0878-augmentation0-128.jpg
# imagens/dataset/person_1-0878-augmentation1-128.xml
# imagens/dataset/person_1-0878-augmentation1-128.jpg
# imagens/dataset/person_1-0878-augmentation0-256.xml
# imagens/dataset/person_1-0878-augmentation0-256.jpg
# imagens/dataset/person_1-0878-augmentation0-256.xml
# imagens/dataset/person_1-0878-augmentation0-256.jpg
# imagens/dataset/person_1-0878-augmentation1-256.xml
# imagens/dataset/person_1-0878-augmentation1-256.jpg
# imagens/dataset/person_1-0878-augmentation0-512.xml
# imagens/dataset/person_1-0878-augmentation0-512.jpg
# imagens/dataset/person_1-0878-augmentation0-512.xml
# imagens/dataset/person_1-0878-augmentation0-512.jpg
# imagens/dataset/person_1-0878-augmentation1-512.xml
# imagens/dataset/person_1-0878-augmentation1-512.jpg
# person_1-0879
# imagens/dataset/person_1-0879-augmentation0-128.xml
# imagens/dataset/person_1-0879-augmentation0-128.jpg
# imagens/dataset/person_1-0879-augmentation0-128.xml
# imagens/dataset/person_1-0879-augmentation0-128.jpg
# imagens/dataset/person_1-0879-augmentation1-128.xml
# imagens/dataset/person_1-0879-augmentation1-128.jpg
# imagens/dataset/person_1-0879-augmentation0-256.xml
# imagens/dataset/person_1-0879-augmentation0-256.jpg
# imagens/dataset/person_1-0879-augmentation0-256.xml
# imagens/dataset/person_1-0879-augmentation0-256.jpg
# imagens/dataset/person_1-0879-augmentation1-256.xml
# imagens/dataset/person_1-0879-augmentation1-256.jpg
# imagens/dataset/person_1-0879-augmentation0-512.xml
# imagens/dataset/person_1-0879-augmentation0-512.jpg
# imagens/dataset/person_1-0879-augmentation0-512.xml
# imagens/dataset/person_1-0879-augmentation0-512.jpg
# imagens/dataset/person_1-0879-augmentation1-512.xml
# imagens/dataset/person_1-0879-augmentation1-512.jpg
# person_1-0880
# imagens/dataset/person_1-0880-augmentation0-128.xml
# imagens/dataset/person_1-0880-augmentation0-128.jpg
# imagens/dataset/person_1-0880-augmentation0-128.xml
# imagens/dataset/person_1-0880-augmentation0-128.jpg
# imagens/dataset/person_1-0880-augmentation1-128.xml
# imagens/dataset/person_1-0880-augmentation1-128.jpg
# imagens/dataset/person_1-0880-augmentation0-256.xml
# imagens/dataset/person_1-0880-augmentation0-256.jpg
# imagens/dataset/person_1-0880-augmentation0-256.xml
# imagens/dataset/person_1-0880-augmentation0-256.jpg
# imagens/dataset/person_1-0880-augmentation1-256.xml
# imagens/dataset/person_1-0880-augmentation1-256.jpg
# imagens/dataset/person_1-0880-augmentation0-512.xml
# imagens/dataset/person_1-0880-augmentation0-512.jpg
# imagens/dataset/person_1-0880-augmentation0-512.xml
# imagens/dataset/person_1-0880-augmentation0-512.jpg
# imagens/dataset/person_1-0880-augmentation1-512.xml
# imagens/dataset/person_1-0880-augmentation1-512.jpg
# person_1-0881
# imagens/dataset/person_1-0881-augmentation0-128.xml
# imagens/dataset/person_1-0881-augmentation0-128.jpg
# imagens/dataset/person_1-0881-augmentation0-128.xml
# imagens/dataset/person_1-0881-augmentation0-128.jpg
# imagens/dataset/person_1-0881-augmentation1-128.xml
# imagens/dataset/person_1-0881-augmentation1-128.jpg
# imagens/dataset/person_1-0881-augmentation0-256.xml
# imagens/dataset/person_1-0881-augmentation0-256.jpg
# imagens/dataset/person_1-0881-augmentation0-256.xml
# imagens/dataset/person_1-0881-augmentation0-256.jpg
# imagens/dataset/person_1-0881-augmentation1-256.xml
# imagens/dataset/person_1-0881-augmentation1-256.jpg
# imagens/dataset/person_1-0881-augmentation0-512.xml
# imagens/dataset/person_1-0881-augmentation0-512.jpg
# imagens/dataset/person_1-0881-augmentation0-512.xml
# imagens/dataset/person_1-0881-augmentation0-512.jpg
# imagens/dataset/person_1-0881-augmentation1-512.xml
# imagens/dataset/person_1-0881-augmentation1-512.jpg
# person_1-0882
# imagens/dataset/person_1-0882-augmentation0-128.xml
# imagens/dataset/person_1-0882-augmentation0-128.jpg
# imagens/dataset/person_1-0882-augmentation0-128.xml
# imagens/dataset/person_1-0882-augmentation0-128.jpg
# imagens/dataset/person_1-0882-augmentation1-128.xml
# imagens/dataset/person_1-0882-augmentation1-128.jpg
# imagens/dataset/person_1-0882-augmentation0-256.xml
# imagens/dataset/person_1-0882-augmentation0-256.jpg
# imagens/dataset/person_1-0882-augmentation0-256.xml
# imagens/dataset/person_1-0882-augmentation0-256.jpg
# imagens/dataset/person_1-0882-augmentation1-256.xml
# imagens/dataset/person_1-0882-augmentation1-256.jpg
# imagens/dataset/person_1-0882-augmentation0-512.xml
# imagens/dataset/person_1-0882-augmentation0-512.jpg
# imagens/dataset/person_1-0882-augmentation0-512.xml
# imagens/dataset/person_1-0882-augmentation0-512.jpg
# imagens/dataset/person_1-0882-augmentation1-512.xml
# imagens/dataset/person_1-0882-augmentation1-512.jpg
# person_1-0883
# imagens/dataset/person_1-0883-augmentation0-128.xml
# imagens/dataset/person_1-0883-augmentation0-128.jpg
# imagens/dataset/person_1-0883-augmentation0-128.xml
# imagens/dataset/person_1-0883-augmentation0-128.jpg
# imagens/dataset/person_1-0883-augmentation1-128.xml
# imagens/dataset/person_1-0883-augmentation1-128.jpg
# imagens/dataset/person_1-0883-augmentation0-256.xml
# imagens/dataset/person_1-0883-augmentation0-256.jpg
# imagens/dataset/person_1-0883-augmentation0-256.xml
# imagens/dataset/person_1-0883-augmentation0-256.jpg
# imagens/dataset/person_1-0883-augmentation1-256.xml
# imagens/dataset/person_1-0883-augmentation1-256.jpg
# imagens/dataset/person_1-0883-augmentation0-512.xml
# imagens/dataset/person_1-0883-augmentation0-512.jpg
# imagens/dataset/person_1-0883-augmentation0-512.xml
# imagens/dataset/person_1-0883-augmentation0-512.jpg
# imagens/dataset/person_1-0883-augmentation1-512.xml
# imagens/dataset/person_1-0883-augmentation1-512.jpg
# person_1-0884
# imagens/dataset/person_1-0884-augmentation0-128.xml
# imagens/dataset/person_1-0884-augmentation0-128.jpg
# imagens/dataset/person_1-0884-augmentation0-128.xml
# imagens/dataset/person_1-0884-augmentation0-128.jpg
# imagens/dataset/person_1-0884-augmentation1-128.xml
# imagens/dataset/person_1-0884-augmentation1-128.jpg
# imagens/dataset/person_1-0884-augmentation0-256.xml
# imagens/dataset/person_1-0884-augmentation0-256.jpg
# imagens/dataset/person_1-0884-augmentation0-256.xml
# imagens/dataset/person_1-0884-augmentation0-256.jpg
# imagens/dataset/person_1-0884-augmentation1-256.xml
# imagens/dataset/person_1-0884-augmentation1-256.jpg
# imagens/dataset/person_1-0884-augmentation0-512.xml
# imagens/dataset/person_1-0884-augmentation0-512.jpg
# imagens/dataset/person_1-0884-augmentation0-512.xml
# imagens/dataset/person_1-0884-augmentation0-512.jpg
# imagens/dataset/person_1-0884-augmentation1-512.xml
# imagens/dataset/person_1-0884-augmentation1-512.jpg
# person_1-0885
# imagens/dataset/person_1-0885-augmentation0-128.xml
# imagens/dataset/person_1-0885-augmentation0-128.jpg
# imagens/dataset/person_1-0885-augmentation0-128.xml
# imagens/dataset/person_1-0885-augmentation0-128.jpg
# imagens/dataset/person_1-0885-augmentation1-128.xml
# imagens/dataset/person_1-0885-augmentation1-128.jpg
# imagens/dataset/person_1-0885-augmentation0-256.xml
# imagens/dataset/person_1-0885-augmentation0-256.jpg
# imagens/dataset/person_1-0885-augmentation0-256.xml
# imagens/dataset/person_1-0885-augmentation0-256.jpg
# imagens/dataset/person_1-0885-augmentation1-256.xml
# imagens/dataset/person_1-0885-augmentation1-256.jpg
# imagens/dataset/person_1-0885-augmentation0-512.xml
# imagens/dataset/person_1-0885-augmentation0-512.jpg
# imagens/dataset/person_1-0885-augmentation0-512.xml
# imagens/dataset/person_1-0885-augmentation0-512.jpg
# imagens/dataset/person_1-0885-augmentation1-512.xml
# imagens/dataset/person_1-0885-augmentation1-512.jpg
# person_1-0886
# imagens/dataset/person_1-0886-augmentation0-128.xml
# imagens/dataset/person_1-0886-augmentation0-128.jpg
# imagens/dataset/person_1-0886-augmentation0-128.xml
# imagens/dataset/person_1-0886-augmentation0-128.jpg
# imagens/dataset/person_1-0886-augmentation1-128.xml
# imagens/dataset/person_1-0886-augmentation1-128.jpg
# imagens/dataset/person_1-0886-augmentation0-256.xml
# imagens/dataset/person_1-0886-augmentation0-256.jpg
# imagens/dataset/person_1-0886-augmentation0-256.xml
# imagens/dataset/person_1-0886-augmentation0-256.jpg
# imagens/dataset/person_1-0886-augmentation1-256.xml
# imagens/dataset/person_1-0886-augmentation1-256.jpg
# imagens/dataset/person_1-0886-augmentation0-512.xml
# imagens/dataset/person_1-0886-augmentation0-512.jpg
# imagens/dataset/person_1-0886-augmentation0-512.xml
# imagens/dataset/person_1-0886-augmentation0-512.jpg
# imagens/dataset/person_1-0886-augmentation1-512.xml
# imagens/dataset/person_1-0886-augmentation1-512.jpg
# person_1-0888
# imagens/dataset/person_1-0888-augmentation0-128.xml
# imagens/dataset/person_1-0888-augmentation0-128.jpg
# imagens/dataset/person_1-0888-augmentation0-128.xml
# imagens/dataset/person_1-0888-augmentation0-128.jpg
# imagens/dataset/person_1-0888-augmentation1-128.xml
# imagens/dataset/person_1-0888-augmentation1-128.jpg
# imagens/dataset/person_1-0888-augmentation0-256.xml
# imagens/dataset/person_1-0888-augmentation0-256.jpg
# imagens/dataset/person_1-0888-augmentation0-256.xml
# imagens/dataset/person_1-0888-augmentation0-256.jpg
# imagens/dataset/person_1-0888-augmentation1-256.xml
# imagens/dataset/person_1-0888-augmentation1-256.jpg
# imagens/dataset/person_1-0888-augmentation0-512.xml
# imagens/dataset/person_1-0888-augmentation0-512.jpg
# imagens/dataset/person_1-0888-augmentation0-512.xml
# imagens/dataset/person_1-0888-augmentation0-512.jpg
# imagens/dataset/person_1-0888-augmentation1-512.xml
# imagens/dataset/person_1-0888-augmentation1-512.jpg
# person_1-0889
# imagens/dataset/person_1-0889-augmentation0-128.xml
# imagens/dataset/person_1-0889-augmentation0-128.jpg
# imagens/dataset/person_1-0889-augmentation0-128.xml
# imagens/dataset/person_1-0889-augmentation0-128.jpg
# imagens/dataset/person_1-0889-augmentation1-128.xml
# imagens/dataset/person_1-0889-augmentation1-128.jpg
# imagens/dataset/person_1-0889-augmentation0-256.xml
# imagens/dataset/person_1-0889-augmentation0-256.jpg
# imagens/dataset/person_1-0889-augmentation0-256.xml
# imagens/dataset/person_1-0889-augmentation0-256.jpg
# imagens/dataset/person_1-0889-augmentation1-256.xml
# imagens/dataset/person_1-0889-augmentation1-256.jpg
# imagens/dataset/person_1-0889-augmentation0-512.xml
# imagens/dataset/person_1-0889-augmentation0-512.jpg
# imagens/dataset/person_1-0889-augmentation0-512.xml
# imagens/dataset/person_1-0889-augmentation0-512.jpg
# imagens/dataset/person_1-0889-augmentation1-512.xml
# imagens/dataset/person_1-0889-augmentation1-512.jpg
# person_1-0890
# imagens/dataset/person_1-0890-augmentation0-128.xml
# imagens/dataset/person_1-0890-augmentation0-128.jpg
# imagens/dataset/person_1-0890-augmentation0-128.xml
# imagens/dataset/person_1-0890-augmentation0-128.jpg
# imagens/dataset/person_1-0890-augmentation1-128.xml
# imagens/dataset/person_1-0890-augmentation1-128.jpg
# imagens/dataset/person_1-0890-augmentation0-256.xml
# imagens/dataset/person_1-0890-augmentation0-256.jpg
# imagens/dataset/person_1-0890-augmentation0-256.xml
# imagens/dataset/person_1-0890-augmentation0-256.jpg
# imagens/dataset/person_1-0890-augmentation1-256.xml
# imagens/dataset/person_1-0890-augmentation1-256.jpg
# imagens/dataset/person_1-0890-augmentation0-512.xml
# imagens/dataset/person_1-0890-augmentation0-512.jpg
# imagens/dataset/person_1-0890-augmentation0-512.xml
# imagens/dataset/person_1-0890-augmentation0-512.jpg
# imagens/dataset/person_1-0890-augmentation1-512.xml
# imagens/dataset/person_1-0890-augmentation1-512.jpg
# person_1-0891
# imagens/dataset/person_1-0891-augmentation0-128.xml
# imagens/dataset/person_1-0891-augmentation0-128.jpg
# imagens/dataset/person_1-0891-augmentation0-128.xml
# imagens/dataset/person_1-0891-augmentation0-128.jpg
# imagens/dataset/person_1-0891-augmentation1-128.xml
# imagens/dataset/person_1-0891-augmentation1-128.jpg
# imagens/dataset/person_1-0891-augmentation0-256.xml
# imagens/dataset/person_1-0891-augmentation0-256.jpg
# imagens/dataset/person_1-0891-augmentation0-256.xml
# imagens/dataset/person_1-0891-augmentation0-256.jpg
# imagens/dataset/person_1-0891-augmentation1-256.xml
# imagens/dataset/person_1-0891-augmentation1-256.jpg
# imagens/dataset/person_1-0891-augmentation0-512.xml
# imagens/dataset/person_1-0891-augmentation0-512.jpg
# imagens/dataset/person_1-0891-augmentation0-512.xml
# imagens/dataset/person_1-0891-augmentation0-512.jpg
# imagens/dataset/person_1-0891-augmentation1-512.xml
# imagens/dataset/person_1-0891-augmentation1-512.jpg
# person_1-0924
# imagens/dataset/person_1-0924-augmentation0-128.xml
# imagens/dataset/person_1-0924-augmentation0-128.jpg
# imagens/dataset/person_1-0924-augmentation0-128.xml
# imagens/dataset/person_1-0924-augmentation0-128.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-3fc2dcd14d07> in <module>
#      15
#      16         for x in range(2):
# ---> 17             gerar_transformacao_aleatoria(img, bboxes, nome, x, dimensao)
#
# <ipython-input-27-df39d517279f> in gerar_transformacao_aleatoria(img, bboxes, nome_arquivo, x, tamanho)
#      25     print(novo_nome)
#      26
# ---> 27     cv2.imwrite(novo_nome,img_[:,:,::-1])
#
# KeyboardInterrupt:

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2
