# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
import os
import io
import pandas as pd
import tensorflow as tf
from PIL import Image
from object_detection.utils import dataset_util

# %%
def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
        value = (root.find('filename').text,
                 int(root.find('size')[0].text),
                 int(root.find('size')[1].text),
                 member[0].text,
                 int(member[4][0].text),
                 int(member[4][1].text),
                 int(member[4][2].text),
                 int(member[4][3].text)
                 )
        arr = [int(member[4][0].text), int(member[4][1].text), int(member[4][2].text), int(member[4][3].text)]
        print(arr)
        return value

# %%
def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        # print(xml_file)
        
        exists_image = os.path.isfile(os.path.splitext(xml_file)[0] + '.jpg')
        
        if(exists_image):        
            value = parse_xml(xml_file)
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)    
    return xml_df

# %%
xml_df
# Out:
#                filename  width  height    class  xmin  ymin  xmax  ymax
# 0     person_1-0763.jpg   1280     720  letra_a   334   302   603   512
# 1     person_1-0764.jpg   1280     720  letra_a   346   298   609   519
# 2     person_1-0765.jpg   1280     720  letra_a   355   297   618   505
# 3     person_1-0766.jpg   1280     720  letra_a   365   292   630   503
# 4     person_1-0767.jpg   1280     720  letra_a   381   280   651   494
# 5     person_1-0768.jpg   1280     720  letra_a   376   292   642   512
# 6     person_1-0769.jpg   1280     720  letra_a   385   300   645   514
# 7     person_1-0770.jpg   1280     720  letra_a   389   298   644   510
# 8     person_1-0771.jpg   1280     720  letra_a   351   312   601   527
# 9     person_1-0772.jpg   1280     720  letra_a   343   313   593   535
# 10    person_1-0778.jpg   1280     720  letra_b   439   219   614   586
# 11    person_1-0779.jpg   1280     720  letra_b   431   231   603   593
# 12    person_1-0780.jpg   1280     720  letra_b   412   243   584   600
# 13    person_1-0781.jpg   1280     720  letra_b   404   231   573   582
# 14    person_1-0782.jpg   1280     720  letra_b   377   240   546   595
# 15    person_1-0783.jpg   1280     720  letra_b   415   231   585   582
# 16    person_1-0784.jpg   1280     720  letra_b   409   246   580   597
# 17    person_1-0785.jpg   1280     720  letra_b   396   250   566   604
# 18    person_1-0786.jpg   1280     720  letra_b   391   252   562   608
# 19    person_1-0789.jpg   1280     720  letra_c   458   260   752   526
# 20    person_1-0790.jpg   1280     720  letra_c   364   273   652   550
# 21    person_1-0791.jpg   1280     720  letra_c   319   262   604   519
# 22    person_1-0792.jpg   1280     720  letra_c   320   247   595   510
# 23    person_1-0793.jpg   1280     720  letra_c   314   244   599   504
# 24    person_1-0794.jpg   1280     720  letra_c   321   225   605   473
