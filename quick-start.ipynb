# %% [markdown]
# # Data Augmentation For Object Detection
#
# This notebook serves as general manual to using this codebase. We cover all the major augmentations, as well as ways to combine them.

# %%
import xml.etree.ElementTree as ET
from data_aug.data_aug import *
from data_aug.bbox_util import *
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
import pickle as pkl
import glob
# %matplotlib inline

# %% [markdown]
# ## Storage Format
#
# First things first, we define how the storage formats required for images to work.
# 1. **The Image**: A OpenCV numpy array, of shape *(H x W x C)*.
# 2. **Annotations**: A numpy array of shape *N x 5* where *N* is the number of objects, one represented by each row. 5 columns represent the top-left x-coordinate, top-left y-coordinate, bottom-right x-coordinate, bottom-right y-coordinate, and the class of the object.
#
# Here is an image to aid your imagination.
#
# ![Annotation Format](ann_form.jpg)
#
# Whatever format your annotations are present in make sure, you convert them to this format.
#
# For demonstration purposes, we will be using the image above to show the transformations. The image as well as it's annotation has been provided. The annotation is a numpy array in a pickled format.

# %%
def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
        value = (root.find('filename').text,
                 int(root.find('size')[0].text),
                 int(root.find('size')[1].text),
                 member[0].text,
                 int(member[4][0].text),
                 int(member[4][1].text),
                 int(member[4][2].text),
                 int(member[4][3].text)
                 )
        arr = [float(member[4][0].text), float(member[4][1].text), float(member[4][2].text), float(member[4][3].text)]
        
    return np.array([arr])

# %%
def create_new_xml(xml_file, arr, new_xml, novo_nome):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
        value = (root.find('filename').text,
                 int(root.find('size')[0].text),
                 int(root.find('size')[1].text),
                 member[0].text,
                 int(member[4][0].text),
                 int(member[4][1].text),
                 int(member[4][2].text),
                 int(member[4][3].text)
                 )
        root.find('filename').text = novo_nome
        root.find('path').text = novo_nome
        member[4][0].text = str(int(arr[0]))
        member[4][1].text = str(int(arr[1]))
        member[4][2].text = str(int(arr[2]))
        member[4][3].text = str(int(arr[3]) )     
        
    tree.write(new_xml)

# %%
img = cv2.imread("person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
bboxes = parse_xml('person_1-0763.xml')

#inspect the bounding boxes
print(bboxes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-24808fcf1a74> in <module>
# ----> 1 img = cv2.imread("person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
#       2 bboxes = parse_xml('person_1-0763.xml')
#       3
#       4 #inspect the bounding boxes
#       5 print(bboxes)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
bboxes
# Out:
# array([[123., 270., 475., 580.]])

# %% [markdown]
# You can use the function `draw_rect` to plot the bounding boxes on an image.

# %%
plotted_img = draw_rect(img, bboxes)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# Now, we can get started with our image augmentations. The first one is **Horizontal Flipping**. The function takes one arguement, *p* which is the probability that the image will be flipped.

# %%
img_, bboxes_ = RandomHorizontalFlip(1)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Scaling**. Scales the image. If the argument *diff* is True, then the image is scaled with different values in the vertical and the horizontal directions, i.e. aspect ratio is not maintained.
#
# If the first argument is a float, then the scaling factors for both x and y directions are randomly sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomScale(0.3, diff = True)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Translation**. Translates the image. If the argument *diff* is True, then the image is translated with different values in the vertical and the horizontal directions.
#
# If the first argument is a float, then the translating factors for both x and y directions are randomly sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomTranslate(0.3, diff = True)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Rotation**. Rotates the image.
#
# If the first argument is a int, then the rotating angle, in degrees, is sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomRotate(10)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Shearing**. Sheares the image horizontally
#
# If the first argument is a float, then the shearing factor is sampled from *(- arg, arg)*. Otherwise, you can specify a tuple for this range.

# %%
img_, bboxes_ = RandomShear(0.2)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# **Resizing**.  Resizes the image to square dimensions while keeping the aspect ratio constant.
#
# The argument to this augmentation is the side of the square.

# %%
img_, bboxes_ = Resize(512)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# HSV transforms are supported as well.

# %%
img_, bboxes_ = RandomHSV(100, 100, 100)(img.copy(), bboxes.copy())
plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# You can combine multiple transforms together by using the Sequence class as follows.

# %%
seq = Sequence([RandomHSV(40, 40, 30),RandomHorizontalFlip(), RandomScale(), RandomTranslate(), RandomRotate(10), RandomShear()])
img_, bboxes_ = seq(img.copy(), bboxes.copy())

plotted_img = draw_rect(img_, bboxes_)
plt.imshow(plotted_img)
plt.show()

# %% [markdown]
# A list of all possible transforms can be found in the `docs` folder.

# %%
img = cv2.imread("person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
bboxes = parse_xml('person_1-0763.xml')

    
plotted_img = draw_rect(img, bboxes)
plt.imshow(plotted_img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-553ac26661b8> in <module>
# ----> 1 img = cv2.imread("person_1-0763.jpg")[:,:,::-1]   #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb
#       2 bboxes = parse_xml('person_1-0763.xml')
#       3
#       4
#       5 plotted_img = draw_rect(img, bboxes)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
bboxes
# Out:
# array([[123., 270., 475., 580.]])

# %%
bboxes[0][1]
# Out:
# 270.0

# %%
def resize_image(img, bboxes, nome_arquivo, x, tamanho):
    img_, bboxes_ = Resize(tamanho)(img.copy(), bboxes.copy())
    novo_xml = '%s-augmentation%d-%d.xml' %  ( nome_arquivo, x, tamanho )
    novo_nome = '%s-augmentation%d-%d.jpg' % ( os.path.splitext(image_file)[0], x, tamanho )
    create_new_xml(xml_file, bboxes_[0], novo_xml, novo_nome)
    cv2.imwrite(novo_nome,img_[:,:,::-1])

# %%
for image_file in glob.glob(os.getcwd() + '/*.jpg'):
    
    
    img = cv2.imread(image_file)[:,:,::-1]    #opencv loads images in bgr. the [:,:,::-1] does bgr -> rgb   
    
    xml_file = os.path.splitext(image_file)[0] + '.xml'
    bboxes = parse_xml(xml_file)
    
    print(image_file)
    
    resize_image(img, bboxes, os.path.splitext(image_file)[0], 0, 128)
    resize_image(img, bboxes, os.path.splitext(image_file)[0], 0, 256)
    resize_image(img, bboxes, os.path.splitext(image_file)[0], 0, 512)
    
    for x in range(1, 11):  
        seq = Sequence([RandomHSV(100, 100, 100),RandomHorizontalFlip(), RandomScale(), RandomTranslate(), RandomRotate(10), RandomShear()])
        img_, bboxes_ = seq(img.copy(), bboxes.copy())
        
        nome_arquivo = os.path.splitext(image_file)[0]
        novo_nome = '%s-augmentation%d.jpg' % ( nome_arquivo, x )
        novo_xml = '%s-augmentation%d.xml' %  ( nome_arquivo, x )
        
        cv2.imwrite(novo_nome,img_[:,:,::-1])
        create_new_xml(xml_file, bboxes_[0], novo_xml, novo_nome)
        
        
        resize_image(img_, bboxes_, nome_arquivo, x, 128)
        resize_image(img_, bboxes_, nome_arquivo, x, 256)
        resize_image(img_, bboxes_, nome_arquivo, x, 512)
# Out:
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0353.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0356.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0357.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0358.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0359.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0360.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0361.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0364.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0365.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0366.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0367.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0368.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0369.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0370.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0372.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0373.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0374.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0375.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0376.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0377.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0378.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0379.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0380.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0381.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0382.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0383.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0398.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_3-0399.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0100.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0127.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0159.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0207.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0338.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0462.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0489.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0515.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0545.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0568.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0614.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0640.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0694.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0722.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_4-0814.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0015.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0016.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0017.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0018.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0019.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0020.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0021.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0022.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0023.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0026.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0027.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0028.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0029.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0030.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0031.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0032.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0033.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0034.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0035.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0038.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0039.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0040.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0041.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0042.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0043.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0044.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0045.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0046.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0047.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0048.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0049.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0050.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0052.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0053.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0054.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0055.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0056.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0057.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0058.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0059.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0060.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0061.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0063.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0064.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0065.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0066.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0067.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0068.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0069.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0070.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0071.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0076.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0077.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0078.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0079.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0080.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0081.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0082.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0083.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0084.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0085.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0088.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0089.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0090.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0091.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0092.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0093.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0094.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0095.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0096.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0097.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0098.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0099.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0116.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0117.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0118.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0119.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0120.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0121.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0122.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0123.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0124.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0151.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0152.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0153.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0154.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0155.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0156.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0157.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0158.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0159.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0160.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0162.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0163.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0164.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0165.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0166.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0167.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0168.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0169.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0170.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0171.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0172.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0173.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0174.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0175.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0176.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0177.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0178.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0179.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0180.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0181.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0182.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0183.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0184.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0185.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0186.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0187.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0190.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0191.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0192.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0193.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0194.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0195.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0196.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0197.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0198.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0203.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0204.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0205.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0206.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0207.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0208.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0209.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0210.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0211.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0212.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0215.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0216.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0217.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0218.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0219.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0220.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0221.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0222.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0223.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0224.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0228.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0229.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0230.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0231.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0232.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0233.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0234.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0235.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0236.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0237.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0240.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0241.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0242.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0243.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0244.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0245.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0246.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0247.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0248.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0252.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0253.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0254.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0255.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0256.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0257.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0258.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0259.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0260.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0261.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0262.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0263.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0266.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0267.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0268.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0269.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0270.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0271.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0272.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0273.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0274.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0275.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0276.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0277.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0278.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0279.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0280.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0281.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0282.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0283.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0284.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0285.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0286.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0319.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0320.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0321.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0322.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0323.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_5-0324.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0041.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0042.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0043.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0044.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0045.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0046.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0047.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0048.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0049.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0050.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0051.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0052.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0053.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0054.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0055.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0056.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0057.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0058.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0059.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0084.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0085.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0086.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0087.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0088.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0089.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0090.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0091.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0092.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0093.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0094.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0095.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0096.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0097.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0098.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0099.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0133.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0134.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0135.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0136.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0137.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0138.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0139.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0140.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0141.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0142.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0143.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0144.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0145.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0163.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0164.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0165.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0166.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0167.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0168.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0180.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0181.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0182.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0183.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0196.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0197.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0198.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0199.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0200.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0201.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0224.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0225.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0226.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0227.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0228.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0229.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0230.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0231.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0232.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0264.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0265.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0266.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0267.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0268.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0269.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0281.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0282.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0283.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0284.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0285.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0286.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0287.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0303.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0304.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0305.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0306.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0307.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0308.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0309.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0310.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0311.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0342.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0343.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0344.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0345.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0346.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0347.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0348.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0349.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0350.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0351.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0352.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0424.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0425.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0426.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0427.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0428.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0429.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0430.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0525.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0526.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0527.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0528.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0529.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0530.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0531.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0532.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0533.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0534.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0564.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0565.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0566.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0567.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0568.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0569.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0570.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0571.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0598.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0599.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0600.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0601.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0602.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0603.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0604.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0605.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0606.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0607.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0639.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0640.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0641.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0642.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0650.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0651.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0652.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0653.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0654.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0655.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0701.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0702.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0703.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0704.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0705.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0706.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0712.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0713.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0714.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0715.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0716.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0717.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0718.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0719.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0720.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0721.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0722.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0723.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0757.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0758.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0759.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0760.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0761.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0762.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0763.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0764.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0765.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0766.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0767.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0768.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0769.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0801.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0802.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0803.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0804.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0805.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0806.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0807.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0808.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0833.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0834.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0835.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0836.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0837.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0838.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0839.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0840.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0841.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0865.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0866.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0867.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0868.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0869.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0878.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0879.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0880.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0881.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0882.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0896.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0897.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0898.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0899.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0900.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0901.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0927.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0928.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0929.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0930.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0931.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0932.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0957.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0958.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0959.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0960.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0961.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0962.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0963.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0964.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-0965.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1075.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1076.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1079.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1080.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1081.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1082.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1083.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1084.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_6-1085.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0247.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0248.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0249.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0250.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0251.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0252.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0253.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0254.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0255.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0256.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0258.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0259.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0260.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0261.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0262.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0263.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0264.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0265.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0267.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0268.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0269.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0270.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0271.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0272.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0273.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0275.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0276.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0277.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0278.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0279.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0280.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0281.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0299.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0300.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0301.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0302.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0303.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0304.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0305.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0306.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0307.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0308.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0309.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0310.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0311.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0312.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0313.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0314.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0315.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0316.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0318.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0319.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0320.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0321.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0322.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0323.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0324.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0326.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0354.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0355.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0364.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0365.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0366.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0368.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0369.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0370.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0371.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0372.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0373.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0423.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0424.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0425.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0426.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0427.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0428.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0429.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0457.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0458.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0459.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0460.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0461.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0462.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0463.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0465.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0466.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0467.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0468.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0471.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0472.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0473.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0474.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0475.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0476.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0478.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0479.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0480.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0481.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0482.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0486.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0487.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0490.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0492.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0495.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0496.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0497.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0500.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0501.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0502.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0503.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0504.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0505.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0506.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0509.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0510.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0511.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0512.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0513.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0514.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0515.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0516.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0517.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0519.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0520.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0521.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0522.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0523.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0524.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0525.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0552.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0553.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0554.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0555.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0559.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0560.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0561.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0562.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0571.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0572.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0573.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0579.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0580.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0581.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0582.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0583.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0584.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0585.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0587.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0588.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0589.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0590.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0591.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0632.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0633.jpg
# C:\Users\usuario\git\DataAugmentationForObjectDetection\person_7-0634.jpg
